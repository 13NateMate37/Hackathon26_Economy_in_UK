# %% [markdown]
# # **You Wanna Live Where?**

# %% [markdown]
# ## Objectives
#
# * Perfrom ETL on the cost_of_living.csv
#
# ## Inputs
#
# * The dataset - cost_of_living.csv
#
# * Libraries containing the tools to do ETL and render visualisations, pandas, numpy, matplotlib, seaborn.
#
# ## Outputs
#
# * Descriptive statistics of the the dataset
#
# * A cleaned .csv for EDA

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\NateM\\Desktop\\CI_DA\\Capston Projects\\Hackathon\\Hackathon_Where_You_Wanna_Live\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\NateM\\Desktop\\CI_DA\\Capston Projects\\Hackathon\\Hackathon_Where_You_Wanna_Live'

# %% [markdown]
# # Import Block

# %% [markdown]
# Libraries required to perfrom operations and visualisations

# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt
import seaborn as sns 

from HelperFuncs import InitialInspect

# %% [markdown]
# ---

# %% [markdown]
# # Section 1- Extract

# %% [markdown]
# Loading the raw .csv into a pandas dataframe

# %%
# Load the dataset into a dataframe
df_raw = pd.read_csv("Dataset/Raw/cost_of_living.csv")

# Verify the dataframe
df_raw.head(5)
# Out:
#              country  cost_of_living_index  rent_index  \
# 0            Bermuda                 135.8       108.2
# 1     Cayman Islands                 115.6        76.1
# 2  US Virgin Islands                 111.3        46.8
# 3        Switzerland                 110.7        51.5
# 4    Solomon Islands                 102.3        19.5
#
#    cost_of_living_plus_rent_index  groceries_index  restaurant_price_index  \
# 0                           123.5            143.4                   147.5
# 1                            97.9            124.0                   101.5
# 2                            82.5            127.4                    94.8
# 3                            84.3            109.7                   111.3
# 4                            65.4             64.8                    46.0
#
#    local_purchasing_power_index  year period      continent
# 0                         101.3  2026   year  North America
# 1                         149.6  2026   year  North America
# 2                          89.8  2026   year  North America
# 3                         170.6  2026   year         Europe
# 4                          12.6  2026   year        Oceania

# %% [markdown]
# Let's inspect the datatypes, check values and duplicates and view a descriptive statistical summary.

# %%
InitialInspect(df_raw)
# Out:
# Initial shape: (Row x Col) (1223, 10)
# ==================================================
# Columns data types:
#  country                            object
# cost_of_living_index              float64
# rent_index                        float64
# cost_of_living_plus_rent_index    float64
# groceries_index                   float64
# restaurant_price_index            float64
# local_purchasing_power_index      float64
# year                                int64
# period                             object
# continent                          object
# dtype: object
# ==================================================
# Missing value counts:
# country: 0.
# cost_of_living_index: 0.
# rent_index: 0.
# cost_of_living_plus_rent_index: 0.
# groceries_index: 0.
# restaurant_price_index: 0.
# local_purchasing_power_index: 0.
# year: 0.
# period: 0.
# continent: 0.
# ==================================================
# Duplicate counts:
# country: 1066 duplicates.
# cost_of_living_index: 657 duplicates.
# rent_index: 823 duplicates.
# cost_of_living_plus_rent_index: 743 duplicates.
# groceries_index: 682 duplicates.
# restaurant_price_index: 640 duplicates.
# local_purchasing_power_index: 496 duplicates.
# year: 1214 duplicates.
# period: 1222 duplicates.
# continent: 1217 duplicates.
# ==================================================
# The .describe summary:
#        cost_of_living_index   rent_index  cost_of_living_plus_rent_index  \
# count           1223.000000  1223.000000                     1223.000000
# mean              48.689534    18.649714                       34.567048
# std               20.221341    14.426711                       16.755419
# min               17.800000     2.000000                       11.000000
# 25%               33.900000     9.500000                       22.550000
# 50%               43.900000    13.900000                       30.200000
# 75%               58.850000    23.100000                       42.600000
# max              146.000000   108.200000                      123.800000
#
#        groceries_index  restaurant_price_index  local_purchasing_power_index  \
# count      1223.000000             1223.000000                   1223.000000
# mean         45.581030               42.212347                     55.999182
# std          19.933582               23.394244                     34.183070
# min          14.900000               12.000000                      1.400000
# 25%          31.200000               25.000000                     30.300000
# 50%          40.500000               35.400000                     46.100000
# 75%          55.250000               53.800000                     79.450000
# max         148.700000              159.200000                    200.800000
#
#               year
# count  1223.000000
# mean   2022.204415
# std       2.555584
# min    2018.000000
# 25%    2020.000000
# 50%    2022.000000
# 75%    2024.000000
# max    2026.000000
# ==================================================
# First 10 rows
#              country  cost_of_living_index  rent_index  \
# 0            Bermuda                 135.8       108.2
# 1     Cayman Islands                 115.6        76.1
# 2  US Virgin Islands                 111.3        46.8
# 3        Switzerland                 110.7        51.5
# 4    Solomon Islands                 102.3        19.5
# 5            Bahamas                  98.8        50.2
# 6            Iceland                  97.2        49.5
# 7             Jersey                  88.7        52.4
# 8          Singapore                  87.7        73.1
# 9             Norway                  83.7        29.2
#
#    cost_of_living_plus_rent_index  groceries_index  restaurant_price_index  \
# 0                           123.5            143.4                   147.5
# 1                            97.9            124.0                   101.5
# 2                            82.5            127.4                    94.8
# 3                            84.3            109.7                   111.3
# 4                            65.4             64.8                    46.0
# 5                            77.1            100.9                   109.0
# 6                            75.9            104.5                   104.9
# 7                            72.5             79.0                   102.3
# 8                            81.2             77.3                    55.5
# 9                            59.4             85.4                    88.6
#
#    local_purchasing_power_index  year period      continent
# 0                         101.3  2026   year  North America
# 1                         149.6  2026   year  North America
# 2                          89.8  2026   year  North America
# 3                         170.6  2026   year         Europe
# 4                          12.6  2026   year        Oceania
# 5                          57.1  2026   year  North America
# 6                         113.7  2026   year         Europe
# 7                         103.4  2026   year         Europe
# 8                         105.5  2026   year           Asia
# 9                         124.7  2026   year         Europe
# ==================================================

# %% [markdown]
# The dataset is very clean. None of the datatypes need correcting. There are no missing values and the duplicates are fine, with recurring values such as the year, continent and country.
#
# The column titles are clear and uniform meaning they don't need to be edited either. The year min and max range also matches the listed description of the dataset.

# %% [markdown]
# ---

# %% [markdown]
# # Section 2 - Transformations

# %% [markdown]
# We'll double check that the country entries are all matching and not containing multiple spellings (UK, Uk, United Kingdom).

# %%
df_raw["country"].value_counts(ascending=True).sort_index()
# Out:
# country
# Afghanistan    6
# Albania        9
# Algeria        9
# Andorra        1
# Angola         1
#               ..
# Venezuela      8
# Vietnam        9
# Yemen          6
# Zambia         7
# Zimbabwe       9
# Name: count, Length: 157, dtype: int64

# %% [markdown]
# There are no multiple entries via seperate spellings.

# %% [markdown]
# With no real changes that need to happen. The dataset is very clean, and has been regularly updated. As individuals, we can carve out our own dataframe segment, focusing on the specific countries assigned to said individual if necessary.
#
# As the dataset contains what we already need to look at and analyse for the project, no features need to be engineered. There could be a case to engineer the "Afforability Rule" that will be the basis for our comparisons here but if we find that that rule needs to be adjusted then that feature would need to be removed as the edited verions is impletement. So it will be kept out of the dataframe for now and will just be something to refer to externally.
#
# This alters the output of this notebook to be more of a 'Validated' dataframe, as aposed to a more conventional 'Cleaned' dataframe.

# %% [markdown]
# ---

# %% [markdown]
# # Section 3 - Loading

# %% [markdown]
# The dataframe will still be loaded into a fresh .csv so that the raw file is left untouched.

# %%
df_raw.to_csv()
# Out:
# ',country,cost_of_living_index,rent_index,cost_of_living_plus_rent_index,groceries_index,restaurant_price_index,local_purchasing_power_index,year,period,continent\r\n0,Bermuda,135.8,108.2,123.5,143.4,147.5,101.3,2026,year,North America\r\n1,Cayman Islands,115.6,76.1,97.9,124.0,101.5,149.6,2026,year,North America\r\n2,US Virgin Islands,111.3,46.8,82.5,127.4,94.8,89.8,2026,year,North America\r\n3,Switzerland,110.7,51.5,84.3,109.7,111.3,170.6,2026,year,Europe\r\n4,Solomon Islands,102.3,19.5,65.4,64.8,46.0,12.6,2026,year,Oceania\r\n5,Bahamas,98.8,50.2,77.1,100.9,109.0,57.1,2026,year,North America\r\n6,Iceland,97.2,49.5,75.9,104.5,104.9,113.7,2026,year,Europe\r\n7,Jersey,88.7,52.4,72.5,79.0,102.3,103.4,2026,year,Europe\r\n8,Singapore,87.7,73.1,81.2,77.3,55.5,105.5,2026,year,Asia\r\n9,Norway,83.7,29.2,59.4,85.4,88.6,124.7,2026,year,Europe\r\n10,Israel,79.7,31.2,58.0,74.0,89.9,119.6,2026,year,Asia\r\n11,Denmark,78.9,28.9,56.6,72.7,93.7,146.6,2026,year,Europe\r\n12,Luxembourg,78.0,49.3,65.2,77.7,83.3,160.5,2026,year,Europe\r\n13,Grenada,76.4,15.8,49.4,68.9,53.5,34.6,2026,year,North America\r\n14,Hong Kong,75.2,63.1,69.8,75.1,51.1,91.6,2026,year,Asia\r\n15,Isle Of Man,74.7,32.0,55.7,65.3,91.8,116.6,2026,year,Europe\r\n16,Guernsey,73.4,55.3,65.3,77.9,71.2,132.8,2026,year,Europe\r\n17,Netherlands,73.4,38.7,57.9,66.9,81.6,131.9,2026,year,Europe\r\n18,Austria,71.3,25.1,50.7,72.6,71.5,120.0,2026,year,Europe\r\n19,Ireland,70.6,43.8,58.7,68.8,76.6,114.4,2026,year,Europe\r\n20,Gibraltar,70.3,56.0,63.9,60.8,78.7,86.1,2026,year,Europe\r\n21,Finland,69.0,21.9,48.0,68.7,74.1,129.4,2026,year,Europe\r\n22,United States,68.8,40.7,56.3,74.0,72.8,146.0,2026,year,North America\r\n23,Germany,68.7,24.6,49.0,64.9,66.9,138.3,2026,year,Europe\r\n24,Belgium,68.6,23.8,48.6,66.4,80.7,124.2,2026,year,Europe\r\n25,Sweden,68.0,22.6,47.8,